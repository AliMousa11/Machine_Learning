# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import OneHotEncoder

# %%
df=pd.read_csv(r"D:\1\Ali\Machine_Learning\Recommendation_System\reducedfile.csv")
df
# Out:
#                        title  tag        artist  year  views  \
# 0                 Complaints  pop      Somatina  2019     68
# 1                       12AM  rap     Lil Macks  2021   6443
# 2                  Fantastic  rap    LMEN PRALA  2021   2027
# 3                  VIOLENT 3  rap     UG Planet  2021    575
# 4                 Snow White  pop  Zack Martino  2021     41
# ...                      ...  ...           ...   ...    ...
# 199995      Ein Böser Scherz  pop      Ewigheim  2015     88
# 199996          Give It More  rap       Canibus  2006    598
# 199997              Picayune  pop          Yori  2018    605
# 199998  아름다운 날 Beautiful day  pop   LUNA (f(x))  2010      4
# 199999      Politics of Love  pop    Gorky Park  1992    327
#
#                                                  features  \
# 0                                                      {}
# 1                                                      {}
# ...

# %%
na=df[df['title'].isna()]
na
# Out:
#        title  tag      artist  year  views features  \
# 4851     NaN  rap      Fresku  2021   1999       {}
# 32827    NaN  pop  Jett Rebel  2014    262       {}
# 100125   NaN  pop   SEULEMENT  2021      1       {}
# 100796   NaN  rap   J4ydizz1e  2018     55       {}
#
#                                                    lyrics       id  \
# 4851    Yeah\nZijn we dan\n\n[Verse]\nHoor mensen zegg...  7324665
# 32827   I got it all figured out\nThink I know what I'...  2323195
# 100125  [Paroles de "++"]\n\n[Couplet 1]\nLa vie est u...  7590029
# 100796  [Intro: J4yDiZz1e]\n\nThis shit sounds just li...  3561848
#
#        language_cld3 language_ft language
# 4851              nl          nl       nl
# 32827             en          en       en
# 100125            fr          fr       fr
# 100796            en          en       en

# %%
df.dropna(subset="title",inplace=True)
df
# Out:
#                        title  tag        artist  year  views  \
# 0                 Complaints  pop      Somatina  2019     68
# 1                       12AM  rap     Lil Macks  2021   6443
# 2                  Fantastic  rap    LMEN PRALA  2021   2027
# 3                  VIOLENT 3  rap     UG Planet  2021    575
# 4                 Snow White  pop  Zack Martino  2021     41
# ...                      ...  ...           ...   ...    ...
# 199995      Ein Böser Scherz  pop      Ewigheim  2015     88
# 199996          Give It More  rap       Canibus  2006    598
# 199997              Picayune  pop          Yori  2018    605
# 199998  아름다운 날 Beautiful day  pop   LUNA (f(x))  2010      4
# 199999      Politics of Love  pop    Gorky Park  1992    327
#
#                                                  features  \
# 0                                                      {}
# 1                                                      {}
# ...

# %%
language_na=df[df['language'].isna()]
language_na
# Out:
#                                          title   tag  \
# 35        Face of Sports: Round of 64 Matchups  misc
# 52                                      Pesona   pop
# 57                                    PARAGONE   rap
# 92                                      Andrew   pop
# 93                            Da Me Trnci Bude   rap
# ...                                        ...   ...
# 199927                               Brun Hund   pop
# 199935             Radio Bemba / Eldorado 1997   pop
# 199937  Carnival Dimitri Vegas  Like Mike Edit   pop
# 199949                                     P.S   pop
# 199966                                 Bel Bel   rap
#
#                                  artist  year  views  \
# 35                        Sports Genius  2015    825
# 52                        Figura Renata  2020     75
# 57                             RO-SMOKE  2020     83
# 92                           Fur Patrol  2015    189
# 93                             Stoposto  2021    119
# ...

# %%
df[df['language_cld3'].isna()]
# Out:
#                                          title   tag  \
# 35        Face of Sports: Round of 64 Matchups  misc
# 92                                      Andrew   pop
# 101        Apink -  I Like That Kiss Romanized   pop
# 188                         I DONT WANNA DANCE   pop
# 225                               Ok All Right   pop
# ...                                        ...   ...
# 199762                        Heron King Blues   pop
# 199811                     Youre my everything   pop
# 199856                         Set Awon no set   pop
# 199927                               Brun Hund   pop
# 199937  Carnival Dimitri Vegas  Like Mike Edit   pop
#
#                                  artist  year  views  \
# 35                        Sports Genius  2015    825
# 92                           Fur Patrol  2015    189
# 101                Genius Romanizations  2018     21
# 188                                ITZY  2020   2611
# 225                             Pato Fu  1995     17
# ...

# %%
df[df['language_ft'].isna()]
# Out:
#                                       title   tag                  artist  \
# 57                                 PARAGONE   rap                RO-SMOKE
# 93                         Da Me Trnci Bude   rap                Stoposto
# 101     Apink -  I Like That Kiss Romanized   pop    Genius Romanizations
# 242      Deutschrap Album Releases Mai 2020  misc  Rap Genius Deutschland
# 249                                Big Bang   pop               Ken Zazpi
# ...                                     ...   ...                     ...
# 199856                      Set Awon no set   pop                Yung kiy
# 199881                             Aquarium   pop              Tiana Xiao
# 199927                            Brun Hund   pop            Roben & Knud
# 199949                                  P.S   pop            Blaq Diamond
# 199966                              Bel Bel   rap                  Elinel
#
#         year  views        features  \
# 57      2020     83              {}
# ...

# %%
df.dropna(subset="language",inplace=True)
df.isna().sum()
# Out:
# title            0
# tag              0
# artist           0
# year             0
# views            0
# features         0
# lyrics           0
# id               0
# language_cld3    0
# language_ft      0
# language         0
# dtype: int64

# %%
df["features"] = df["features"].str.replace('{}','None')
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4660\1380700443.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["features"] = df["features"].str.replace('{}','None')
#                        title  tag        artist  year  views  \
# 0                 Complaints  pop      Somatina  2019     68
# 1                       12AM  rap     Lil Macks  2021   6443
# 2                  Fantastic  rap    LMEN PRALA  2021   2027
# 3                  VIOLENT 3  rap     UG Planet  2021    575
# 4                 Snow White  pop  Zack Martino  2021     41
# ...                      ...  ...           ...   ...    ...
# 199995      Ein Böser Scherz  pop      Ewigheim  2015     88
# 199996          Give It More  rap       Canibus  2006    598
# 199997              Picayune  pop          Yori  2018    605
# 199998  아름다운 날 Beautiful day  pop   LUNA (f(x))  2010      4
# 199999      Politics of Love  pop    Gorky Park  1992    327
#
# ...

# %%
df.isna().sum()
# Out:
# title            0
# tag              0
# artist           0
# year             0
# views            0
# features         0
# lyrics           0
# id               0
# language_cld3    0
# language_ft      0
# language         0
# dtype: int64

# %%
for x in df.index:
    if df.loc[x,'year']<1900:
        df.drop(x,inplace=True)
df
# Out:
#                        title  tag        artist  year  views  \
# 0                 Complaints  pop      Somatina  2019     68
# 1                       12AM  rap     Lil Macks  2021   6443
# 2                  Fantastic  rap    LMEN PRALA  2021   2027
# 3                  VIOLENT 3  rap     UG Planet  2021    575
# 4                 Snow White  pop  Zack Martino  2021     41
# ...                      ...  ...           ...   ...    ...
# 199995      Ein Böser Scherz  pop      Ewigheim  2015     88
# 199996          Give It More  rap       Canibus  2006    598
# 199997              Picayune  pop          Yori  2018    605
# 199998  아름다운 날 Beautiful day  pop   LUNA (f(x))  2010      4
# 199999      Politics of Love  pop    Gorky Park  1992    327
#
#                                                  features  \
# 0                                                    None
# 1                                                    None
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#                        title  tag        artist  year  views  \
# 0                 Complaints  pop      Somatina  2019     68
# 1                       12AM  rap     Lil Macks  2021   6443
# 2                  Fantastic  rap    LMEN PRALA  2021   2027
# 3                  VIOLENT 3  rap     UG Planet  2021    575
# 4                 Snow White  pop  Zack Martino  2021     41
# ...                      ...  ...           ...   ...    ...
# 199995      Ein Böser Scherz  pop      Ewigheim  2015     88
# 199996          Give It More  rap       Canibus  2006    598
# 199997              Picayune  pop          Yori  2018    605
# 199998  아름다운 날 Beautiful day  pop   LUNA (f(x))  2010      4
# 199999      Politics of Love  pop    Gorky Park  1992    327
#
#                                                  features  \
# 0                                                    None
# 1                                                    None
# ...

# %%
df.to_csv(r"D:\1\Ali\Machine_Learning\Recommendation_System\cleanedfile.csv", index=False)
